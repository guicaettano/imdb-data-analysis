# %%
import pandas as pd
imdb_data = pd.read_csv('imdb_top_1000.csv')
imdb_data
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
i = imdb_data[imdb_data["Series_Title"]=='Donnie Darko']
print(i)

# %%
nan_df = imdb_data[imdb_data.isna().any(axis=1)]

imdb_data = imdb_data.dropna(how='all')
imdb_data.drop(imdb_data.columns[[0, 7, 8]], axis=1, inplace=True)
imdb_data.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating              Director           Star1  \
# 0                 Drama          9.3        Frank Darabont     Tim Robbins
# 1          Crime, Drama          9.2  Francis Ford Coppola   Marlon Brando
# 2  Action, Crime, Drama          9.0     Christopher Nolan  Christian Bale
# 3          Crime, Drama          9.0  Francis Ford Coppola       Al Pacino
# 4          Crime, Drama          9.0          Sidney Lumet     Henry Fonda
#
#             Star2          Star3           Star4  No_of_Votes        Gross
# ...

# %%
imdb_data = imdb_data.sort_values('IMDB_Rating', ascending = False)
imdb_data.head(20)
# Out:
#                                          Series_Title Released_Year  \
# 0                            The Shawshank Redemption          1994
# 1                                       The Godfather          1972
# 2                                     The Dark Knight          2008
# 3                              The Godfather: Part II          1974
# 4                                        12 Angry Men          1957
# 5       The Lord of the Rings: The Return of the King          2003
# 6                                        Pulp Fiction          1994
# 7                                    Schindler's List          1993
# 10  The Lord of the Rings: The Fellowship of the Ring          2001
# 11                                       Forrest Gump          1994
# 12                    Il buono, il brutto, il cattivo          1966
# 9                                          Fight Club          1999
# 8                                           Inception          2010
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5880\3744126402.py in <module>
# ----> 1 imdb_data['Gross'].sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11072             **kwargs,
#   11073         ):
# > 11074             return NDFrame.sum(
#   11075                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   11076             )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10792         **kwargs,
#   10793     ):
# > 10794         return self._min_count_stat_function(
#   10795             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10796         )
#
# ...
